# %% [markdown]
# ## <span style="color:brown">Notebook Instructions</span>
#
# <i> You can run the notebook document sequentially (one cell a time) by pressing <b> shift + enter </b>. While a cell is running, In [*] will display on the left. When it has been run, a number will display indicating the order in which it was run in the notebook. Example: In [8]: </i>
#
# <i> Enter edit mode by pressing <b> Enter </b> or using the mouse to click on a cell's editor area. Edit mode is indicated by a green cell border and a prompt showing in the editor area. </i>

# %% [markdown]
# ##### <span style="color:green">1. Create Data Frames </span>
# ##### <span style="color:green">2. Customize index of a Data Frame</span>
# #####  <span style="color:green">3. Rearrange the columns in a Data Frame</span>
# ##### <span style="color:green">4. Use an Existing Column as the index of a Data Frame</span>
# ##### <span style="color:green">5. Access a column in a Data Frame</span>
# ##### <span style="color:green">6. Load financial market data </span>
# ##### <span style="color:green">7. Dropping Rows and/or Columns</span>
# ##### <span style="color:green">8. Rename columns</span>
# ##### <span style="color:green">9. Sort a Data Frame using a column</span>
# ##### <span style="color:green">10. Just for Fun</span>

# %% [markdown]
# ## Create Data Frames
#
# The underlying idea of a Data Frame is based on 'spreadsheets'. In other words, data frames store data in discrete Rows and Columns, where each column can be named (something that is not possible in Arrays but is possible in Series). There are also multiple columns in a Data Frame (as opposed to Series, where there can be only one discrete indexed column).<br>
# <br>
# The constructor for a Data Frame is <font color=red>pandas.DataFrame(data=None, index=None)</font> or if you are using 'pd' as alias for pandas, then it would be <font color=red>pd.DataFrame(data=None, index=None)</font><br>
# <br>
# Let us have a look at the following example.

# %%
import pandas as pd
import numpy as np

# A DataFrame has a row and a column index

my_portfolio = {
                "stock_name": ["Alphabet", "Facebook", "Apple", "Tesla", "Infosys"],
                "quantity_owned": [1564, 6546, 5464, 6513, 4155],
                "average_buy_price": ["$950", "$160", "$120", "$270", "$15"]
               } 

my_portfolio_frame = pd.DataFrame (my_portfolio) # We have passed the 'data' argument in the Data Frame constructor

my_portfolio_frame #This is a dataframe
# Out:
#   average_buy_price  quantity_owned stock_name
# 0              $950            1564   Alphabet
# 1              $160            6546   Facebook
# 2              $120            5464      Apple
# 3              $270            6513      Tesla
# 4               $15            4155    Infosys

# %% [markdown]
# ## Customize index of the Data Frame
#
# In the above output, you can see that the 'index' is the default one which starts from 0. One can customize this index.

# %%
ordinals = ["first", "second", "third", "fourth", "fifth"] # list

my_portfolio_frame = pd.DataFrame (my_portfolio, index=ordinals) #Please notice that we have not kept index as default i.e.'none'

my_portfolio_frame
# Out:
#        average_buy_price  quantity_owned stock_name
# first               $950            1564   Alphabet
# second              $160            6546   Facebook
# third               $120            5464      Apple
# fourth              $270            6513      Tesla
# fifth                $15            4155    Infosys

# %% [markdown]
# ## Rearrange the columns in a Data Frame
#
# We can also define or change the order of columns.

# %%
# you can define the order of columns using the parameter columns=[] in the construction statement

my_portfolio_frame = pd.DataFrame(my_portfolio, columns=["stock_name", "quantity_owned", "average_buy_price"], index=ordinals)

my_portfolio_frame
# Out:
#        stock_name  quantity_owned average_buy_price
# first    Alphabet            1564              $950
# second   Facebook            6546              $160
# third       Apple            5464              $120
# fourth      Tesla            6513              $270
# fifth     Infosys            4155               $15

# %% [markdown]
# ## Use an existing column as an index of a dataframe
#
# We will use the column 'stock_name' as the index of the dataframe.

# %%
my_portfolio_frame = pd.DataFrame (my_portfolio, 
                                   columns = ["quantity_owned","average_buy_price"],
                                   index = my_portfolio ["stock_name"])

my_portfolio_frame
# Out:
#           quantity_owned average_buy_price
# Alphabet            1564              $950
# Facebook            6546              $160
# Apple               5464              $120
# Tesla               6513              $270
# Infosys             4155               $15

# %% [markdown]
# ## Access a column in a data frame
#
# You can access or retrieve a single or multiple columns by their names or by their location.

# %%
# The index at present is the 'stock_name'. Refer to above code. 

# This makes sense if we just want to know the quantity of stock that we own for each stock (which is our index, currently)

print (my_portfolio_frame["quantity_owned"]) # Column name is passed within quotes within square brackets
# Out:
# Alphabet    1564
# Facebook    6546
# Apple       5464
# Tesla       6513
# Infosys     4155
# Name: quantity_owned, dtype: int64

# %% [markdown]
# Give an example to retrieve column using location no.

# %% [markdown]
# ## Load financial market data
#
# This is a recap from the section 'Importing Data and Data Visualisation'. We have done this in a <b>pd.read_csv()</b> iPython notebook.

# %%
# Loading data using CSV file 

# We have stored a 'infy_data.csv'

import numpy as np
import pandas as pd

infy = pd.read_csv ('infy.csv')

# %%
infy # this is our entire "Infosys" stock data frame
# Out:
#     Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 0     INFY     EQ  18-Apr-2016     1172.70     1250.00     1267.90    1233.50
# 1     INFY     EQ  20-Apr-2016     1238.70     1244.00     1246.45    1225.80
# 2     INFY     EQ  21-Apr-2016     1243.60     1251.00     1251.00    1218.10
# 3     INFY     EQ  22-Apr-2016     1226.30     1226.30     1228.50    1207.00
# 4     INFY     EQ  25-Apr-2016     1211.25     1212.05     1224.80    1201.10
# 5     INFY     EQ  26-Apr-2016     1215.85     1215.45     1239.55    1208.60
# 6     INFY     EQ  27-Apr-2016     1232.15     1229.20     1242.35    1228.55
# 7     INFY     EQ  28-Apr-2016     1240.15     1231.00     1239.60    1207.00
# 8     INFY     EQ  29-Apr-2016     1209.15     1211.45     1223.55    1205.00
# 9     INFY     EQ  02-May-2016     1208.10     1210.00     1211.15    1196.15
# 10    INFY     EQ  03-May-2016     1201.05     1202.75     1212.20    1171.80
# ...

# %%
infy.head () # You will see the top 5 rows
# Out:
#   Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 0   INFY     EQ  18-Apr-2016     1172.70     1250.00     1267.90     1233.5
# 1   INFY     EQ  20-Apr-2016     1238.70     1244.00     1246.45     1225.8
# 2   INFY     EQ  21-Apr-2016     1243.60     1251.00     1251.00     1218.1
# 3   INFY     EQ  22-Apr-2016     1226.30     1226.30     1228.50     1207.0
# 4   INFY     EQ  25-Apr-2016     1211.25     1212.05     1224.80     1201.1
#
#    Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0     1237.15      1238.70        1247.17               12507995
# 1     1244.00      1243.60        1237.18                4036424
# 2     1226.80      1226.30        1231.52                2720550
# 3     1212.75      1211.25        1215.94                2571969
# 4     1219.25      1215.85        1211.42                2682067
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# ...

# %%
infy.tail () # You will see the bottom 5 rows
# Out:
#     Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 490   INFY     EQ  09-Apr-2018     1127.00     1125.00     1125.80    1106.55
# 491   INFY     EQ  10-Apr-2018     1111.25     1112.00     1124.50    1105.40
# 492   INFY     EQ  11-Apr-2018     1113.40     1118.00     1131.50    1116.50
# 493   INFY     EQ  12-Apr-2018     1124.25     1129.45     1172.75    1125.00
# 494   INFY     EQ  13-Apr-2018     1162.60     1174.00     1185.90    1150.25
#
#      Last Price  Close Price  Average Price  Total Traded Quantity  \
# 490     1111.45      1111.25        1113.12                3601441
# 491     1114.65      1113.40        1115.77                4463029
# 492     1124.50      1124.25        1124.78                4512787
# 493     1164.05      1162.60        1157.71                8522183
# 494     1168.00      1171.45        1172.37               10613519
#
#          Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# ...

# %% [markdown]
# ## Dropping Rows and/or Columns
#
# In the above Infosys stock data, it is not necessary that you need all the columns which are present in the .csv file. Hence, to make your data frame more understandable, you may drop the columns that you do not need using drop function.<br>
# <br>
# General Syntax for dropping columns:<br>
# <pre>DataFrame.drop(['Column_name'])</pre>
# General Syntax for dropping rows:<br>
# <pre>DataFrame.drop(DataFrame.index[[x,y,z...]]</pre>
# where x,y,z are row index values

# %%
# The axis=1 represents that we are considering columns while dropping.

infy_new = infy.drop (['Prev Close', 'Last Price', 'Average Price', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'Symbol','Series'], axis = 1)

infy_new.head ()
# Out:
#           Date  Open Price  High Price  Low Price  Close Price  \
# 0  18-Apr-2016     1250.00     1267.90     1233.5      1238.70
# 1  20-Apr-2016     1244.00     1246.45     1225.8      1243.60
# 2  21-Apr-2016     1251.00     1251.00     1218.1      1226.30
# 3  22-Apr-2016     1226.30     1228.50     1207.0      1211.25
# 4  25-Apr-2016     1212.05     1224.80     1201.1      1215.85
#
#    Deliverable Qty  % Dly Qt to Traded Qty
# 0          7270261                   58.12
# 1          2555094                   63.30
# 2          1626993                   59.80
# 3          1634111                   63.54
# 4          1673309                   62.39

# %%
# Dropping rows: 31 March2016, 01 April 2016

infy_new.drop (infy_new.index [[3,4]] ).head() #ADD comment and explain [[3,4]] Also give an example to drop columns using this syntax
# Out:
#           Date  Open Price  High Price  Low Price  Close Price  \
# 0  18-Apr-2016     1250.00     1267.90    1233.50      1238.70
# 1  20-Apr-2016     1244.00     1246.45    1225.80      1243.60
# 2  21-Apr-2016     1251.00     1251.00    1218.10      1226.30
# 5  26-Apr-2016     1215.45     1239.55    1208.60      1232.15
# 6  27-Apr-2016     1229.20     1242.35    1228.55      1240.15
#
#    Deliverable Qty  % Dly Qt to Traded Qty
# 0          7270261                   58.12
# 1          2555094                   63.30
# 2          1626993                   59.80
# 5          1829934                   62.60
# 6          1582665                   70.56

# %% [markdown]
# ## Rename Columns
#
# If we want to rename the column names, while dealing with the data frame we need to use the rename function.

# %%
# Renaming Columns: Have a quick look at the code, It should be self-explanatory by now

infy_new=infy_new.rename(columns={'Date':'Date','Open Price':'Open','High Price':'High','Low Price':'Low','Close Price':'Close'})

infy_new.head()
# Out:
#           Date     Open     High     Low    Close  Deliverable Qty  \
# 0  18-Apr-2016  1250.00  1267.90  1233.5  1238.70          7270261
# 1  20-Apr-2016  1244.00  1246.45  1225.8  1243.60          2555094
# 2  21-Apr-2016  1251.00  1251.00  1218.1  1226.30          1626993
# 3  22-Apr-2016  1226.30  1228.50  1207.0  1211.25          1634111
# 4  25-Apr-2016  1212.05  1224.80  1201.1  1215.85          1673309
#
#    % Dly Qt to Traded Qty
# 0                   58.12
# 1                   63.30
# 2                   59.80
# 3                   63.54
# 4                   62.39

# %% [markdown]
# ## Sort a Data Frame using a column
#
# Sometimes it becomes necessary to sort a stock price data frame, based on the 'Closing Price'.

# %%
# Sorting Dataframe in descending order

infy_new = infy_new.sort_values(by="Close", ascending=False)

print(infy_new).head(20) #Prints top 20 values of closing prices in the given dataset
# Out:
#            Date     Open     High      Low    Close  Deliverable Qty  \
# 29  30-May-2016  1241.50  1272.00  1241.50  1267.60          1938752
# 33  03-Jun-2016  1260.05  1279.30  1260.05  1266.90          1395872
# 34  06-Jun-2016  1264.90  1277.00  1261.10  1266.75          1515515
# 32  02-Jun-2016  1255.00  1274.90  1254.00  1261.55          1657794
# 31  01-Jun-2016  1246.05  1268.50  1246.00  1258.20          1589552
# 35  07-Jun-2016  1267.00  1272.50  1255.10  1257.40          2314800
# 30  31-May-2016  1265.00  1266.75  1239.00  1248.65          5308966
# 28  27-May-2016  1231.60  1259.50  1231.60  1247.50          2203990
# 1   20-Apr-2016  1244.00  1246.45  1225.80  1243.60          2555094
# 6   27-Apr-2016  1229.20  1242.35  1228.55  1240.15          1582665
# 0   18-Apr-2016  1250.00  1267.90  1233.50  1238.70          7270261
# 36  08-Jun-2016  1263.95  1263.95  1235.35  1238.10          3499200
# 27  26-May-2016  1210.10  1239.80  1210.10  1234.15          2359311
# ...

# %% [markdown]
# ## Just for Fun

# %%
# Create a customized data frame with random numbers between 50k to 120k.

import numpy as np
names = ['Jay', 'Varun', 'Devang', 'Ishan', 'Vibhu']

months = ["January", "February", "March",
         "April", "May", "June",
         "July", "August", "September",
         "October", "November", "December"]

df = pd.DataFrame(np.random.randn (12, 5)*10000, columns = names, index = months)

df
# Out:
#                     Jay         Varun        Devang        Ishan         Vibhu
# January   -20080.099388   5445.868643   5029.691943   518.548992   9049.504269
# February    5667.785500   6136.172613   -411.027183   257.887293    881.372458
# March      -2160.868657  -4121.932082  14740.261857  3908.063334  -6176.950066
# April       3581.326047 -19589.805194  15942.791578 -6495.753581 -10751.033674
# May         5057.147225  -3366.955375 -19097.811285  9207.073489  14601.932551
# June       -2549.281093  -4168.322267  11987.202377  8860.043743 -19454.326744
# July       -1036.384065  16932.851409 -13684.555723 -3605.093204   4991.444274
# August      3389.105282  13816.027404  -7786.394280  3201.381921   4588.306455
# September  -7589.623331  -4065.239463  -9050.772036 -5424.294709    611.958987
# October     4413.692409  -6349.019280   -550.965854 -3968.881623  -4316.842728
# November    8339.979367   6028.019747 -10167.624981  5535.141102    732.490233
# ...

# %% [markdown]
# ### <span style="color:green">In the upcoming iPython Notebook:</span> <br>
# We will understand <b>Descriptive Statistical Functions</b> on a Data Frame but before that a few quiz questions and exercises on this.
